# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# data : tips
#
# target : tip
#
# preprocess:
# 1. one hot encoding : sex, smoker, time
# 2. binary encoding : day
# 3. robust scaler : total_bill
# 4. no treatment : size
# Random state 10, data splitting 70:30 model Ridge default

# %%
enc_df = pd.get_dummies(df[['sex', 'smoker', 'time', 'day']], drop_first=True)
enc_df
# Out:
#      sex_Female  smoker_No  time_Dinner  day_Fri  day_Sat  day_Sun
# 0          True       True         True    False    False     True
# 1         False       True         True    False    False     True
# 2         False       True         True    False    False     True
# 3         False       True         True    False    False     True
# 4          True       True         True    False    False     True
# ..          ...        ...          ...      ...      ...      ...
# 239       False       True         True    False     True    False
# 240        True      False         True    False     True    False
# 241       False      False         True    False     True    False
# 242       False       True         True    False     True    False
# 243        True       True         True    False    False    False
#
# [244 rows x 6 columns]

# %%
clean_df = pd.concat([df[['total_bill', 'tip', 'size']], enc_df], axis = 1)
clean_df
# Out:
#      total_bill   tip  size  sex_Female  smoker_No  time_Dinner  day_Fri  \
# 0         16.99  1.01     2        True       True         True    False
# 1         10.34  1.66     3       False       True         True    False
# 2         21.01  3.50     3       False       True         True    False
# 3         23.68  3.31     2       False       True         True    False
# 4         24.59  3.61     4        True       True         True    False
# ..          ...   ...   ...         ...        ...          ...      ...
# 239       29.03  5.92     3       False       True         True    False
# 240       27.18  2.00     2        True      False         True    False
# 241       22.67  2.00     2       False      False         True    False
# 242       17.82  1.75     2       False       True         True    False
# 243       18.78  3.00     2        True       True         True    False
#
#      day_Sat  day_Sun
# 0      False     True
# 1      False     True
# 2      False     True
# 3      False     True
# 4      False     True
# ..       ...      ...
# 239     True    False
# 240     True    False
# 241     True    False
# 242     True    False
# 243    False    False
#
# [244 rows x 9 columns]

# %%
X = clean_df.drop(columns='tip')
y = clean_df['tip']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
rb = RobustScaler()
rb.fit(X_train[['total_bill']])
# Out:
# RobustScaler()

# %%
X_train['total_bill'] = rb.transform(X_train[['total_bill']])
X_test['total_bill'] = rb.transform(X_test[['total_bill']])

# %%
X_train
# Out:
#      total_bill  size  sex_Female  smoker_No  time_Dinner  day_Fri  day_Sat  \
# 69    -0.254450     2       False      False         True    False     True
# 79    -0.054054     2       False       True        False    False    False
# 8     -0.251813     2       False       True         True    False    False
# 105   -0.223687     2       False      False         True    False     True
# 230    0.536585     4       False      False         True    False     True
# ..          ...   ...         ...        ...          ...      ...      ...
# 145   -0.839815     2        True       True        False    False    False
# 14    -0.270270     2        True       True         True    False    False
# 206    0.763349     3       False      False         True    False     True
# 7      0.788838     4       False       True         True    False    False
# 99    -0.478576     2       False       True         True     True    False
#
#      day_Sun
# 69     False
# 79     False
# 8       True
# 105    False
# 230    False
# ..       ...
# 145    False
# 14      True
# 206    False
# 7       True
# 99     False
#
# [170 rows x 8 columns]

# %%
X_train.describe()
# Out:
#        total_bill        size
# count  170.000000  170.000000
# mean     0.172694    2.529412
# std      0.783991    0.884960
# min     -1.303889    1.000000
# 25%     -0.404526    2.000000
# 50%      0.000000    2.000000
# 75%      0.595474    3.000000
# max      2.674138    6.000000

# %%
X_test.describe()
# Out:
#        total_bill       size
# count   74.000000  74.000000
# mean     0.148384   2.662162
# std      0.783996   1.088886
# min     -1.068337   1.000000
# 25%     -0.382773   2.000000
# 50%     -0.065041   2.000000
# 75%      0.353329   3.000000
# max      2.892112   6.000000

# %%
ridge = Ridge()

# %%
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 1.233079189092444
